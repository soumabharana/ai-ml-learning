# %% [markdown]
# #Basic Programmings

# %%
### Programming Basics

#* **Algorithm:** Step by step instructions to solve any problem.
#* **Programming:** A way of writing these instructions in a language that the computer understands.
#* **Programming Languages:** C, C++, Python, Java, JavaScript...

### Why Python?
#1. **Easy to understand:** Programmer friendly.
#2. **Rich set of Libraries:** AI, ML, Web Dev, Automation...

### Hello World Program (C++ vs Python)

# C++ Implementation (for conceptual reference)
#"""
#include <iostream>
#using namespace std;

#int main() {
#    cout << "Hello World";
 #   return 0;
#}
#"""

# Python Implementation
#print("Hello World")

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A","B","C")
# Out:
# A B C

# %%
print("3+2")
# Out:
# 3+2
