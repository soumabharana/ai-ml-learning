# %%
p=""
password = "Password@321"

while p!=password:
  p = input()
print("Correct Password")
# Out:
# nkk
# sksjjjdjdj
# Password@321
# Correct Password

# %%
for i in range(1,11):
  if i==5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
password = "Pass@321"
while True:
  p = input("Enter Password: ")
  if p==password:
    print("Correct Password")
    break
  else:
    print("Incorrect Password")
# Out:
# Enter Password: The
# Incorrect Password
# Enter Password: Jk
# Incorrect Password
# Enter Password: JJK
# Incorrect Password
# Enter Password: One Piece
# Incorrect Password
# Enter Password: Pass@321
# Correct Password

# %%
for i in range(1,11):
  if i%2!=0:
    continue
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# Program to demonstrate 'continue' and 'break' inside a loop

for i in range(1, 11):
    if i % 2 != 0:
        continue
    if i > 7:
        break
    print(i)
# Out:
# 2
# 4
# 6
