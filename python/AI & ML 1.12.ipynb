# %%
s = "Aditya Jain likes to do programming"

# %%
a = split.s(" ")
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1466/2765322449.py in <cell line: 0>()
# ----> 1 a = split.s(" ")
#
# NameError: name 'split' is not defined

# %%
chr(128526)
# Out:
# '😎'
