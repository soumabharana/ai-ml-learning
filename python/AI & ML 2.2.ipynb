# %%
chr(65)
# Out:
# 'A'

# %%
data = {}
data["A"]=10
data["B"]=20
data["C"]=30
print(len(data))
# Out:
# 3

# %%
days = ["sunday", "monday"]
print(days)
# Out:
# ['sunday', 'monday']

# %%
def show():
  return 2

# %%
a = show()
print(a)
# Out:
# 2
