# %%
student = {
    "Math":80,
    "Science":90,
    "English":85
}
for k in student:
  if student[k]>=85:
    print(k)
# Out:
# Science
# English

# %%
students =[
    "Rahul",
    "Amit",
    "Rahul",
    "Neha",
    "Amit",
    "Rahul"
]
new =[]
for k in students:
  if k not in new:
    new.append(k)
print(new)
# Out:
# ['Rahul', 'Amit', 'Neha']
