# %%
class Car:
  def __init__(self,brand):
    self.brand = brand

car1 = Car("BMW")
car2 = car1

car2.brand = "Audi"
print(car1.brand)
# Out:
# Audi

# %% [markdown]
# #Error Handling

# %%
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3301/244804411.py in <cell line: 0>()
# ----> 1 Print("Hello")
#
# NameError: name 'Print' is not defined

# %%
print("Hello"
# Out:
#   File "/tmp/ipykernel_3301/1647630127.py", line 1
#     print("Hello"
#                  ^
# _IncompleteInputError: incomplete input

# %%
if 10>5
  print("Hello")
# Out:
#   File "/tmp/ipykernel_3301/3445344166.py", line 1
#     if 10>5
#            ^
# SyntaxError: expected ':'

# %%
if 10>5:
print("Hello")
# Out:
#   File "/tmp/ipykernel_3301/350778045.py", line 2
#     print("Hello")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
a=10
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3301/1926354841.py in <cell line: 0>()
#       1 a=10
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
print(b/a)
# Out:
# 0.0

# %%
a=[3,7,5]
print(a[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3301/440648527.py in <cell line: 0>()
#       1 a=[3,7,5]
# ----> 2 print(a[4])
#
# IndexError: list index out of range

# %%
age = int(input("Enter your age: "))
# Out:
# Enter your age: aditya
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3301/3464842140.py in <cell line: 0>()
# ----> 1 age = int(input("Enter your age: "))
#
# ValueError: invalid literal for int() with base 10: 'aditya'

# %%
try:
  n = int(input())
  print(100/n)
except:
  print("Some error has occured!")
# Out:
# 5
# 20.0

# %%
try:
  n = int(input())
  print(100/n)
except:
  print("Some error has occured!")
# Out:
# 0
# Some error has occured!

# %% [markdown]
# #Catching Error

# %%
try:
  n = int(input())
  print(100/n)
except Exception as e:
  print(e)
# Out:
# aditya
# invalid literal for int() with base 10: 'aditya'

# %%
try:
  n = int(input())
  print(100/n)
except Exception as e:
  print(e)
# Out:
# 0
# division by zero

# %%
try:
  n = int(input())
  print(100/n)
except Exception as e:
  print(e)
# Out:
# 20
# 5.0

# %%
try:
    n = int(input())
    print(100 / n)

except ZeroDivisionError:
    print("Division by 0 is not allowed")
except ValueError:
    print("Please enter numbers only")
# Out:
# 0
# Division by 0 is not allowed

# %%
try:
    n = int(input())
    print(100 / n)

except ZeroDivisionError:
    print("Division by 0 is not allowed")
except ValueError:
    print("Please enter numbers only")
# Out:
# aditya
# Please enter numbers only
