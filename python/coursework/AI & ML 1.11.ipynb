# %%
a=[4,6,7,2,1]
n=len(a)
for i in range(n):
  print(a[n-i-1])
# Out:
# 1
# 2
# 7
# 6
# 4

# %%
a=[5,7,4,8,2,1,9]
print(a)

# %%
print(a[2:5])
# Out:
# [4, 8, 2]

# %% [markdown]
# #Strings

# %%
email = "aditya@aj.com"

# %%
#empty string
s=""
print(s)

# %%
s=""
print(s)
len(s)
# Out:
# 0

# %%
word = input("Enter Word: ")
count = 0
for ch in word:
  if ch in "aeiouAEIOU":
    count +=1
print(count)
# Out:
# Enter Word: Amritsar
# 3
