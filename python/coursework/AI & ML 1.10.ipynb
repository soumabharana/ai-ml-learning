# %% [markdown]
# #List

# %%
marks = [90,86,95,83,70]

# %%
marks
# Out:
# [90, 86, 95, 83, 70]

# %%
marks[1]
# Out:
# 86

# %%
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
n =len(marks)
print(n)
# Out:
# 5

# %%
marks[2]=97

# %%
for i in range(n):
  print(marks[i])
# Out:
# 90
# 86
# 97
# 83
# 70

# %%
for i in range(n):
  if i%2==0:
    print(marks[i])
# Out:
# 90
# 97
# 70

# %%
for elem in marks:
  if elem%2==0:
    print(elem)
# Out:
# 90
# 86
# 70

# %%
marks=[60,70,80,90]
print(max(marks))
# Out:
# 90

# %%
marks=[60,70,80,90]
sm=0
for elem in marks:
  sm = sm+elem
print(sm)
# Out:
# 300

# %%
type(elem)
# Out:
# int

# %%
marks=[60,70,80,90]
sm =0
for elem in marks:
  sm = sm+elem
avg = sm/len(marks)
print(avg)
# Out:
# 75.0

# %%
sum(marks)
# Out:
# 300

# %%
marks=[60,70,80,90]
avg = sum(marks)/len(marks)
print(avg)
# Out:
# 75.0
