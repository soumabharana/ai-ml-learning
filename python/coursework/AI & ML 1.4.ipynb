# %% [markdown]
# #Decision Making

# %%
Syntax:
if condition:
  statements.....

# %%
age = int(input("Enter your age:"))
if age>=20:
  print("Eligible to vote")
# Out:
# Enter your age:23
# Eligible to vote

# %%
age = int(input("Enter your age:"))
if age>=20:
  print("Eligible to vote")
else:
   print("Not eligible to vote")
# Out:
# Enter your age:18
# Not eligible to vote

# %%
password = input("Enter your passwrd: ")
if password == "hello@123":
  print("Welcome")
else:
  print("Invalid Password")
# Out:
# Enter your passwrd: hello@123
# Welcome

# %%
password = input("Enter your passwrd: ")
if password == "hello@123":
  print("Welcome")
else:
  print("Invalid Password")
# Out:
# Enter your passwrd: Hello
# Invalid Password

# %%
marks = int(input("Enter Marks: "))
if marks<30:
  print("Low")
elif (marks<=70):
  print("Avg")
else:
  print("High")
# Out:
# Enter Marks: 35
# Avg
