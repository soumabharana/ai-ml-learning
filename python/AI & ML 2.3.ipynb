# %%
#Give a string and write a code to turn it lower without using lower()
words = input("Enter word: ")
for word in words:
  if ord(word) >= 65 and ord(word) <= 90:
    print(chr(ord(word) + 32), end="")
  else:
    print(word, end="")
# Out:
# Enter word: Apple
# apple
